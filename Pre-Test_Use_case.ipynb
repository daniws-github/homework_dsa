# %%
import pandas as pd

# %%
df = pd.read_csv('dataset/churn.csv')
df.head(10)
# Out:
#    state  account_length  area_code  phone_number  international_plan  \
# 0     16             128        415          2845                   0
# 1     35             107        415          2301                   0
# 2     31             137        415          1616                   0
# 3     35              84        408          2510                   1
# 4     36              75        415           155                   1
# 5      1             118        510          3355                   1
# 6     19             121        510          1516                   0
# 7     24             147        415           116                   1
# 8     18             117        408           425                   0
# 9     49             141        415           163                   1
#
#    voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                1                     25              265.1              110
# ...

# %%
# remove target and ID columns because the arbitrary ID data isn't relevant to the analysis
features = df[df.columns.difference(['area_code', 'phone_number', 'class'])]

# target
targets = df[['class']]

# %% [markdown]
# ### Q1

# %%
features.describe()
# Out:
#        account_length  international_plan  number_customer_service_calls  \
# count      5000.00000         5000.000000                    5000.000000
# mean        100.25860            0.094600                       1.570400
# std          39.69456            0.292691                       1.306363
# min           1.00000            0.000000                       0.000000
# 25%          73.00000            0.000000                       1.000000
# 50%         100.00000            0.000000                       1.000000
# 75%         127.00000            0.000000                       2.000000
# max         243.00000            1.000000                       9.000000
#
#        number_vmail_messages       state  total_day_calls  total_day_charge  \
# count            5000.000000  5000.00000      5000.000000       5000.000000
# mean                7.755200    25.99840       100.029400         30.649668
# std                13.546393    14.80348        19.831197          9.162069
# ...

# %%
features.shape
# Out:
# (5000, 18)

# %% [markdown]
# ### Q2

# %%
features.isna().sum()
# Out:
# account_length                   0
# international_plan               0
# number_customer_service_calls    0
# number_vmail_messages            0
# state                            0
# total_day_calls                  0
# total_day_charge                 0
# total_day_minutes                0
# total_eve_calls                  0
# total_eve_charge                 0
# total_eve_minutes                0
# total_intl_calls                 0
# total_intl_charge                0
# total_intl_minutes               0
# total_night_calls                0
# total_night_charge               0
# total_night_minutes              0
# voice_mail_plan                  0
# dtype: int64

# %% [markdown]
# ### Q3

# %%
total = df.shape[0]
churn = df.groupby('class').number_customer_service_calls.count()[1]

churn_persen = churn / total

print('{:.2%} of the base are classified as churn'.format(churn_persen))
# Out:
# 14.14% of the base are classified as churn

# %% [markdown]
# ### Q4

# %%
cs_call3x = df[df['number_customer_service_calls'] >= 3]
x,y = cs_call3x.groupby('class').state.count()

z = y / (x+y)

print('{:.2%} of the customers who called the company more than 3 times are classified as Churn'.format(z))
# Out:
# 25.75% of the customers who called the company more than 3 times are classified as Churn

# %% [markdown]
# ### Q5

# %%
ir_call = df[df['international_plan'] == 0]
x,y = ir_call.groupby('class').state.count()
z = y / (x+y)

print('{:.2%} of those with no international plan are classified as Churn'.format(z))
# Out:
# 11.22% of those with no international plan are classified as Churn
